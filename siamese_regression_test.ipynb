# %%
from model import ConvRegression
from dataset import ConvRegressionTestDataset, ConvRegressionTrainDataset, _load
from torch.utils.data import DataLoader
from train import TrainConvRegression


model = ConvRegression()

folderpath = 'bareface/crop_part1'
x_train, y_train, x_test, y_test = _load(folderpath, 50)
train_dataset = ConvRegressionTrainDataset(x_train, y_train)
test_dataset = ConvRegressionTestDataset(x_test, y_test)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=True)

tcr = TrainConvRegression(model, train_dataloader, test_dataloader)
tcr.train(40)
# Out:
# training loss =  621.6273040771484
# test loss =  1166.1712036132812
# training loss =  400.7040100097656
# test loss =  721.63720703125
# training loss =  459.1813049316406
# test loss =  813.8607788085938
# training loss =  486.57269287109375
# test loss =  510.1723937988281
# training loss =  255.6421127319336
# test loss =  428.18641662597656
# training loss =  202.30091094970703
# test loss =  566.9105072021484
# training loss =  686.6958618164062
# test loss =  304.5727996826172
# training loss =  236.89136505126953
# test loss =  502.9073791503906
# training loss =  236.8882827758789
# test loss =  335.0082244873047
# training loss =  283.44456481933594
# test loss =  400.4039840698242
# training loss =  328.75526428222656
# test loss =  261.5625762939453
# training loss =  317.90638732910156
# test loss =  460.85784912109375
# training loss =  584.8526611328125
# test loss =  324.96483612060547
# training loss =  213.76073455810547
# test loss =  237.8152961730957
# ...

# %%
from model import SiameseRegression, SiameseRegressionLoss
from dataset import SiameseRegressionTestDataset, SiameseRegressionTrainDataset, _load
from train import TrainSiameseRegression
from torch.utils.data import DataLoader

model = SiameseRegression()
criterion = SiameseRegressionLoss()

train_dataset = SiameseRegressionTrainDataset(x_train, y_train)
test_dataset = SiameseRegressionTestDataset(x_test, y_test)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=True)

tsr = TrainSiameseRegression(model, train_dataloader, test_dataloader)
tsr.train(40)
# Out:
# training loss =  25317.90771484375
# test loss =  36043.859375
# training loss =  28644.2685546875
# test loss =  37457.578125
# training loss =  16255.833984375
# test loss =  23780.740234375
# training loss =  14952.7197265625
# test loss =  26141.705078125
# training loss =  21356.029296875
# test loss =  31943.419921875
# training loss =  23655.900390625
# test loss =  18727.50537109375
# training loss =  17110.0771484375
# test loss =  29248.1015625
# training loss =  21776.87890625
# test loss =  27581.50390625
# training loss =  22684.0888671875
# test loss =  32960.359375
# training loss =  12882.6396484375
# test loss =  21641.8408203125
# training loss =  12569.8974609375
# test loss =  16016.3623046875
# training loss =  20123.5283203125
# test loss =  24926.728515625
# training loss =  29664.740234375
# test loss =  21150.287109375
# training loss =  20093.076171875
# test loss =  19097.3837890625
# training loss =  16964.76611328125
# test loss =  14687.67578125
# ...
